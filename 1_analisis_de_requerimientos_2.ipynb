# %% [markdown]
# Course: COmputación en la nube.
#
# Module: 3 Modelos de servicio.
#
# Student name: Luis Felipe Castañeda Gallego.

# %% [markdown]
# ## 1. Introduction to the Fiscal Year 2023 Data Loading Notebook
#
# This Jupyter notebook has been created to loading and initial processing of the fiscal year 2023 contract data. Given the large volume and complexity of the dataset, the notebook is structured to ensure efficient handling, loading, and preliminary inspection of the data, which forms the basis for further detailed analysis in the subsequent notebook '3_create_labels_for_fy_2023_companies.ipynb'.
#
# ##### Notebook Objectives:
# - **Data Loading**: Load the extensive CSV files containing detailed contract information for the fiscal year 2023. This process includes reading the data into a pandas DataFrame, which serves as the primary data structure for further operations.
# - **Initial Data Cleaning**: Perform basic cleaning steps that prepare the data for analysis. This includes removing unnecessary columns that do not contribute to the analytical objectives.
# - **Data Inspection**: Provide an initial inspection and summary of the data, allowing for an immediate understanding of its structure and key columns.
#
# #### Why Separate Data Loading?
# Separating the data loading process into its own notebook allows for more manageable code and focuses on ensuring that the data integrity is maintained from the source to the analytical environment. This separation is particularly important for performance optimization when dealing with large datasets, as it allows for specific tuning and adjustments without affecting other analytical processes.

# %% [markdown]
# ## 2. Load and read de data

# %% [markdown]
# Import pandas library.

# %%
import pandas as pd

# %% [markdown]
# Load the first part of the fiscal year 2023 contract data from a csv. This file is part of a series of datasets split across multiple files for manageability. It was loaded in order to know the column structure of the rest of the csv files.

# %%
raw_data_1 = pd.read_csv("..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_1.csv")
# Out:
# C:\Users\lufec\AppData\Local\Temp\ipykernel_3916\3016214842.py:2: DtypeWarning: Columns (47,71,72,81,115,135,136,164,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data_1 = pd.read_csv("..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_1.csv")

# %% [markdown]
# Configure pandas display options to increases the maximum number of columns displayed when using the .info().

# %%
pd.set_option('display.max_info_columns', 300)

# %% [markdown]
# Inspect the DataFrame structure and content.

# %%
raw_data_1.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 297 columns):
#  #    Column                                                          Non-Null Count    Dtype
# ---   ------                                                          --------------    -----
#  0    contract_transaction_unique_key                                 1000000 non-null  object
#  1    contract_award_unique_key                                       1000000 non-null  object
#  2    award_id_piid                                                   1000000 non-null  object
#  3    modification_number                                             1000000 non-null  object
#  4    transaction_number                                              973039 non-null   float64
#  5    parent_award_agency_id                                          816678 non-null   object
#  6    parent_award_agency_name                                        816678 non-null   object
#  7    parent_award_id_piid                                            816691 non-null   object
#  8    parent_award_modification_number                                816691 non-null   object
#  9    federal_action_obligation                                       1000000 non-null  float64
#  10   total_dollars_obligated                                         1000000 non-null  float64
#  11   total_outlayed_amount_for_overall_award                         463570 non-null   float64
#  12   base_and_exercised_options_value                                973039 non-null   float64
#  13   current_total_value_of_award                                    973039 non-null   float64
#  14   base_and_all_options_value                                      1000000 non-null  float64
#  15   potential_total_value_of_award                                  1000000 non-null  float64
#  16   disaster_emergency_fund_codes_for_overall_award                 868192 non-null   object
#  17   outlayed_amount_from_COVID-19_supplementals_for_overall_award   6992 non-null     float64
#  18   obligated_amount_from_COVID-19_supplementals_for_overall_award  8522 non-null     float64
#  19   outlayed_amount_from_IIJA_supplemental_for_overall_award        2950 non-null     float64
#  20   obligated_amount_from_IIJA_supplemental_for_overall_award       3129 non-null     float64
#  21   action_date                                                     1000000 non-null  object
#  22   action_date_fiscal_year                                         1000000 non-null  int64
#  23   period_of_performance_start_date                                1000000 non-null  object
#  24   period_of_performance_current_end_date                          973039 non-null   object
#  25   period_of_performance_potential_end_date                        973039 non-null   object
#  26   ordering_period_end_date                                        26961 non-null    object
#  27   solicitation_date                                               796880 non-null   object
#  28   awarding_agency_code                                            1000000 non-null  int64
#  29   awarding_agency_name                                            1000000 non-null  object
#  30   awarding_sub_agency_code                                        1000000 non-null  object
#  31   awarding_sub_agency_name                                        1000000 non-null  object
#  32   awarding_office_code                                            1000000 non-null  object
#  33   awarding_office_name                                            1000000 non-null  object
#  34   funding_agency_code                                             1000000 non-null  int64
#  35   funding_agency_name                                             1000000 non-null  object
#  36   funding_sub_agency_code                                         1000000 non-null  object
#  37   funding_sub_agency_name                                         1000000 non-null  object
#  38   funding_office_code                                             1000000 non-null  object
#  39   funding_office_name                                             997629 non-null   object
#  40   treasury_accounts_funding_this_award                            869983 non-null   object
#  41   federal_accounts_funding_this_award                             869983 non-null   object
#  42   object_classes_funding_this_award                               869983 non-null   object
#  43   program_activities_funding_this_award                           868497 non-null   object
#  44   foreign_funding                                                 1000000 non-null  object
#  45   foreign_funding_description                                     1000000 non-null  object
#  46   sam_exception                                                   359 non-null      float64
#  47   sam_exception_description                                       359 non-null      object
#  48   recipient_uei                                                   1000000 non-null  object
#  49   recipient_duns                                                  0 non-null        float64
#  50   recipient_name                                                  999998 non-null   object
#  51   recipient_name_raw                                              999986 non-null   object
#  52   recipient_doing_business_as_name                                17283 non-null    object
#  53   cage_code                                                       999709 non-null   object
#  54   recipient_parent_uei                                            999830 non-null   object
#  55   recipient_parent_duns                                           0 non-null        float64
#  56   recipient_parent_name                                           999851 non-null   object
#  57   recipient_parent_name_raw                                       999158 non-null   object
#  58   recipient_country_code                                          999992 non-null   object
#  59   recipient_country_name                                          999972 non-null   object
#  60   recipient_address_line_1                                        999989 non-null   object
#  61   recipient_address_line_2                                        56476 non-null    object
#  62   recipient_city_name                                             999990 non-null   object
#  63   prime_award_transaction_recipient_county_fips_code              978557 non-null   float64
#  64   recipient_county_name                                           978555 non-null   object
#  65   prime_award_transaction_recipient_state_fips_code               979327 non-null   float64
#  66   recipient_state_code                                            979332 non-null   object
#  67   recipient_state_name                                            989511 non-null   object
#  68   recipient_zip_4_code                                            997449 non-null   object
#  69   prime_award_transaction_recipient_cd_original                   321723 non-null   object
#  70   prime_award_transaction_recipient_cd_current                    979332 non-null   object
#  71   recipient_phone_number                                          982913 non-null   object
#  72   recipient_fax_number                                            635516 non-null   object
#  73   primary_place_of_performance_country_code                       973039 non-null   object
#  74   primary_place_of_performance_country_name                       973039 non-null   object
#  75   primary_place_of_performance_city_name                          941909 non-null   object
#  76   prime_award_transaction_place_of_performance_county_fips_code   941917 non-null   float64
#  77   primary_place_of_performance_county_name                        941917 non-null   object
#  78   prime_award_transaction_place_of_performance_state_fips_code    941917 non-null   float64
#  79   primary_place_of_performance_state_code                         941996 non-null   object
#  80   primary_place_of_performance_state_name                         941996 non-null   object
#  81   primary_place_of_performance_zip_4                              947010 non-null   object
#  82   prime_award_transaction_place_of_performance_cd_original        941917 non-null   object
#  83   prime_award_transaction_place_of_performance_cd_current         941996 non-null   object
#  84   award_or_idv_flag                                               1000000 non-null  object
#  85   award_type_code                                                 973039 non-null   object
#  86   award_type                                                      973039 non-null   object
#  87   idv_type_code                                                   26961 non-null    object
#  88   idv_type                                                        26961 non-null    object
#  89   multiple_or_single_award_idv_code                               26958 non-null    object
#  90   multiple_or_single_award_idv                                    26958 non-null    object
#  91   type_of_idc_code                                                15365 non-null    object
#  92   type_of_idc                                                     15365 non-null    object
#  93   type_of_contract_pricing_code                                   999997 non-null   object
#  94   type_of_contract_pricing                                        999997 non-null   object
#  95   transaction_description                                         999909 non-null   object
#  96   prime_award_base_transaction_description                        999833 non-null   object
#  97   action_type_code                                                180499 non-null   object
#  98   action_type                                                     180499 non-null   object
#  99   solicitation_identifier                                         168592 non-null   object
#  100  number_of_actions                                               973039 non-null   float64
#  101  inherently_governmental_functions                               193278 non-null   object
#  102  inherently_governmental_functions_description                   193278 non-null   object
#  103  product_or_service_code                                         999999 non-null   object
#  104  product_or_service_code_description                             999999 non-null   object
#  105  contract_bundling_code                                          999963 non-null   object
#  106  contract_bundling                                               999963 non-null   object
#  107  dod_claimant_program_code                                       48737 non-null    object
#  108  dod_claimant_program_description                                48737 non-null    object
#  109  naics_code                                                      999990 non-null   float64
#  110  naics_description                                               999990 non-null   object
#  111  recovered_materials_sustainability_code                         988440 non-null   object
#  112  recovered_materials_sustainability                              988440 non-null   object
#  113  domestic_or_foreign_entity_code                                 988366 non-null   object
#  114  domestic_or_foreign_entity                                      988366 non-null   object
#  115  dod_acquisition_program_code                                    631833 non-null   object
#  116  dod_acquisition_program_description                             631830 non-null   object
#  117  information_technology_commercial_item_category_code            630947 non-null   object
#  118  information_technology_commercial_item_category                 630947 non-null   object
#  119  epa_designated_product_code                                     973007 non-null   object
#  120  epa_designated_product                                          973007 non-null   object
#  121  country_of_product_or_service_origin_code                       972954 non-null   object
#  122  country_of_product_or_service_origin                            972954 non-null   object
#  123  place_of_manufacture_code                                       972875 non-null   object
#  124  place_of_manufacture                                            972875 non-null   object
#  125  subcontracting_plan_code                                        873547 non-null   object
#  126  subcontracting_plan                                             873547 non-null   object
#  127  extent_competed_code                                            997429 non-null   object
#  128  extent_competed                                                 997429 non-null   object
#  129  solicitation_procedures_code                                    997151 non-null   object
#  130  solicitation_procedures                                         997151 non-null   object
#  131  type_of_set_aside_code                                          218043 non-null   object
#  132  type_of_set_aside                                               218043 non-null   object
#  133  evaluated_preference_code                                       996560 non-null   object
#  134  evaluated_preference                                            996560 non-null   object
#  135  research_code                                                   2322 non-null     object
#  136  research                                                        2322 non-null     object
#  137  fair_opportunity_limited_sources_code                           220538 non-null   object
#  138  fair_opportunity_limited_sources                                220538 non-null   object
#  139  other_than_full_and_open_competition_code                       149730 non-null   object
#  140  other_than_full_and_open_competition                            149730 non-null   object
#  141  number_of_offers_received                                       342258 non-null   float64
#  142  commercial_item_acquisition_procedures_code                     999475 non-null   object
#  143  commercial_item_acquisition_procedures                          999475 non-null   object
#  144  small_business_competitiveness_demonstration_program            1000000 non-null  object
#  145  simplified_procedures_for_certain_commercial_items_code         994652 non-null   object
#  146  simplified_procedures_for_certain_commercial_items              994652 non-null   object
#  147  a76_fair_act_action_code                                        783081 non-null   object
#  148  a76_fair_act_action                                             783081 non-null   object
#  149  fed_biz_opps_code                                               864936 non-null   object
#  150  fed_biz_opps                                                    864936 non-null   object
#  151  local_area_set_aside_code                                       996388 non-null   object
#  152  local_area_set_aside                                            996388 non-null   object
#  153  price_evaluation_adjustment_preference_percent_difference       32817 non-null    float64
#  154  clinger_cohen_act_planning_code                                 999994 non-null   object
#  155  clinger_cohen_act_planning                                      999994 non-null   object
#  156  materials_supplies_articles_equipment_code                      999994 non-null   object
#  157  materials_supplies_articles_equipment                           999994 non-null   object
#  158  labor_standards_code                                            999995 non-null   object
#  159  labor_standards                                                 999995 non-null   object
#  160  construction_wage_rate_requirements_code                        999992 non-null   object
#  161  construction_wage_rate_requirements                             999992 non-null   object
#  162  interagency_contracting_authority_code                          1000000 non-null  object
#  163  interagency_contracting_authority                               1000000 non-null  object
#  164  other_statutory_authority                                       4001 non-null     object
#  165  program_acronym                                                 1630 non-null     object
#  166  parent_award_type_code                                          816672 non-null   object
#  167  parent_award_type                                               816672 non-null   object
#  168  parent_award_single_or_multiple_code                            816638 non-null   object
#  169  parent_award_single_or_multiple                                 816638 non-null   object
#  170  major_program                                                   123139 non-null   object
#  171  national_interest_action_code                                   1000000 non-null  object
#  172  national_interest_action                                        1000000 non-null  object
#  173  cost_or_pricing_data_code                                       699843 non-null   object
#  174  cost_or_pricing_data                                            699843 non-null   object
#  175  cost_accounting_standards_clause_code                           817459 non-null   object
#  176  cost_accounting_standards_clause                                817459 non-null   object
#  177  government_furnished_property_code                              1000000 non-null  object
#  178  government_furnished_property                                   1000000 non-null  object
#  179  sea_transportation_code                                         53472 non-null    object
#  180  sea_transportation                                              53472 non-null    object
#  181  undefinitized_action_code                                       993298 non-null   object
#  182  undefinitized_action                                            993298 non-null   object
#  183  consolidated_contract_code                                      997643 non-null   object
#  184  consolidated_contract                                           997643 non-null   object
#  185  performance_based_service_acquisition_code                      999998 non-null   object
#  186  performance_based_service_acquisition                           1000000 non-null  object
#  187  multi_year_contract_code                                        689439 non-null   object
#  188  multi_year_contract                                             689439 non-null   object
#  189  contract_financing_code                                         644775 non-null   object
#  190  contract_financing                                              644775 non-null   object
#  191  purchase_card_as_payment_method_code                            973039 non-null   object
#  192  purchase_card_as_payment_method                                 973039 non-null   object
#  193  contingency_humanitarian_or_peacekeeping_operation_code         992285 non-null   object
#  194  contingency_humanitarian_or_peacekeeping_operation              992285 non-null   object
#  195  alaskan_native_corporation_owned_firm                           1000000 non-null  object
#  196  american_indian_owned_business                                  1000000 non-null  object
#  197  indian_tribe_federally_recognized                               1000000 non-null  object
#  198  native_hawaiian_organization_owned_firm                         1000000 non-null  object
#  199  tribally_owned_firm                                             1000000 non-null  object
#  200  veteran_owned_business                                          1000000 non-null  object
#  201  service_disabled_veteran_owned_business                         1000000 non-null  object
#  202  woman_owned_business                                            1000000 non-null  object
#  203  women_owned_small_business                                      1000000 non-null  object
#  204  economically_disadvantaged_women_owned_small_business           1000000 non-null  object
#  205  joint_venture_women_owned_small_business                        1000000 non-null  object
#  206  joint_venture_economic_disadvantaged_women_owned_small_bus      1000000 non-null  object
#  207  minority_owned_business                                         1000000 non-null  object
#  208  subcontinent_asian_asian_indian_american_owned_business         1000000 non-null  object
#  209  asian_pacific_american_owned_business                           1000000 non-null  object
#  210  black_american_owned_business                                   1000000 non-null  object
#  211  hispanic_american_owned_business                                1000000 non-null  object
#  212  native_american_owned_business                                  1000000 non-null  object
#  213  other_minority_owned_business                                   1000000 non-null  object
#  214  contracting_officers_determination_of_business_size             1000000 non-null  object
#  215  contracting_officers_determination_of_business_size_code        1000000 non-null  object
#  216  emerging_small_business                                         1000000 non-null  object
#  217  community_developed_corporation_owned_firm                      1000000 non-null  object
#  218  labor_surplus_area_firm                                         1000000 non-null  object
#  219  us_federal_government                                           1000000 non-null  object
#  220  federally_funded_research_and_development_corp                  1000000 non-null  object
#  221  federal_agency                                                  1000000 non-null  object
#  222  us_state_government                                             1000000 non-null  object
#  223  us_local_government                                             1000000 non-null  object
#  224  city_local_government                                           1000000 non-null  object
#  225  county_local_government                                         1000000 non-null  object
#  226  inter_municipal_local_government                                1000000 non-null  object
#  227  local_government_owned                                          1000000 non-null  object
#  228  municipality_local_government                                   1000000 non-null  object
#  229  school_district_local_government                                1000000 non-null  object
#  230  township_local_government                                       1000000 non-null  object
#  231  us_tribal_government                                            1000000 non-null  object
#  232  foreign_government                                              1000000 non-null  object
#  233  organizational_type                                             986216 non-null   object
#  234  corporate_entity_not_tax_exempt                                 1000000 non-null  object
#  235  corporate_entity_tax_exempt                                     1000000 non-null  object
#  236  partnership_or_limited_liability_partnership                    1000000 non-null  object
#  237  sole_proprietorship                                             1000000 non-null  object
#  238  small_agricultural_cooperative                                  1000000 non-null  object
#  239  international_organization                                      1000000 non-null  object
#  240  us_government_entity                                            1000000 non-null  object
#  241  community_development_corporation                               1000000 non-null  object
#  242  domestic_shelter                                                1000000 non-null  object
#  243  educational_institution                                         1000000 non-null  object
#  244  foundation                                                      1000000 non-null  object
#  245  hospital_flag                                                   1000000 non-null  object
#  246  manufacturer_of_goods                                           1000000 non-null  object
#  247  veterinary_hospital                                             1000000 non-null  object
#  248  hispanic_servicing_institution                                  1000000 non-null  object
#  249  receives_contracts                                              1000000 non-null  object
#  250  receives_financial_assistance                                   1000000 non-null  object
#  251  receives_contracts_and_financial_assistance                     1000000 non-null  object
#  252  airport_authority                                               1000000 non-null  object
#  253  council_of_governments                                          1000000 non-null  object
#  254  housing_authorities_public_tribal                               1000000 non-null  object
#  255  interstate_entity                                               1000000 non-null  object
#  256  planning_commission                                             1000000 non-null  object
#  257  port_authority                                                  1000000 non-null  object
#  258  transit_authority                                               1000000 non-null  object
#  259  subchapter_scorporation                                         1000000 non-null  object
#  260  limited_liability_corporation                                   1000000 non-null  object
#  261  foreign_owned                                                   1000000 non-null  object
#  262  for_profit_organization                                         1000000 non-null  object
#  263  nonprofit_organization                                          1000000 non-null  object
#  264  other_not_for_profit_organization                               1000000 non-null  object
#  265  the_ability_one_program                                         1000000 non-null  object
#  266  private_university_or_college                                   1000000 non-null  object
#  267  state_controlled_institution_of_higher_learning                 1000000 non-null  object
#  268  1862_land_grant_college                                         1000000 non-null  object
#  269  1890_land_grant_college                                         1000000 non-null  object
#  270  1994_land_grant_college                                         1000000 non-null  object
#  271  minority_institution                                            1000000 non-null  object
#  272  historically_black_college                                      1000000 non-null  object
#  273  tribal_college                                                  1000000 non-null  object
#  274  alaskan_native_servicing_institution                            1000000 non-null  object
#  275  native_hawaiian_servicing_institution                           1000000 non-null  object
#  276  school_of_forestry                                              1000000 non-null  object
#  277  veterinary_college                                              1000000 non-null  object
#  278  dot_certified_disadvantage                                      1000000 non-null  object
#  279  self_certified_small_disadvantaged_business                     1000000 non-null  object
#  280  small_disadvantaged_business                                    1000000 non-null  object
#  281  c8a_program_participant                                         1000000 non-null  object
#  282  historically_underutilized_business_zone_hubzone_firm           1000000 non-null  object
#  283  sba_certified_8a_joint_venture                                  1000000 non-null  object
#  284  highly_compensated_officer_1_name                               130159 non-null   object
#  285  highly_compensated_officer_1_amount                             130159 non-null   float64
#  286  highly_compensated_officer_2_name                               128239 non-null   object
#  287  highly_compensated_officer_2_amount                             128239 non-null   float64
#  288  highly_compensated_officer_3_name                               124477 non-null   object
#  289  highly_compensated_officer_3_amount                             124477 non-null   float64
#  290  highly_compensated_officer_4_name                               124878 non-null   object
#  291  highly_compensated_officer_4_amount                             124878 non-null   float64
#  292  highly_compensated_officer_5_name                               122007 non-null   object
#  293  highly_compensated_officer_5_amount                             122007 non-null   float64
#  294  usaspending_permalink                                           1000000 non-null  object
#  295  initial_report_date                                             1000000 non-null  object
#  296  last_modified_date                                              1000000 non-null  object
# dtypes: float64(28), int64(3), object(266)
# memory usage: 2.2+ GB

# %% [markdown]
# Create a list of paths for all the csv files that contain the data of the fiscal year 2023 contracts.

# %%
file_paths = [
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_1.csv",
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_2.csv",
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_3.csv",
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_4.csv",
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_5.csv",
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_6.csv",
    "..\\Data\\FY2023_All_Contracts_Full_20240408\\FY2023_All_Contracts_Full_20240409_7.csv",
    ]

# %% [markdown]
# After look at the raw_data_1 structure, create a list of potencial columns of interest. Specify the columns for data loading helps to focus the analysis on relevant information and enhances performance by reducing memory usage.

# %%
cols_to_use = [
    "federal_action_obligation",
    "total_dollars_obligated",
    "current_total_value_of_award",
    "potential_total_value_of_award",
    "period_of_performance_start_date",
    "period_of_performance_current_end_date",
    "period_of_performance_potential_end_date",
    "awarding_agency_name",
    "funding_agency_name",
    "recipient_uei",
    "recipient_name",
    "recipient_country_name",
    "recipient_state_code",
    "recipient_state_name",
    "primary_place_of_performance_country_code",
    "primary_place_of_performance_country_name",
    "primary_place_of_performance_state_code",
    "primary_place_of_performance_state_name",
    "award_or_idv_flag",
    "award_type",
    "product_or_service_code",
    "product_or_service_code_description",
    "type_of_contract_pricing",
    "naics_code",
    "naics_description",
    "extent_competed",
    "c8a_program_participant",
]

# %% [markdown]
# Load and concatenate the data from the multiple file paths, creating an empty DataFrame fy2023_all_contracts to store the data, then looping over each file path, loading the data with the usecols parameter to limit the process to the columns of interest and optimizing memory usage. And concatenate merging the temporary DataFrame temp_df with the main DataFrame, reindexing the combined DataFrame.

# %%
fy2023_all_contracts = pd.DataFrame()

for path in file_paths:
    temp_df = pd.read_csv(path, usecols=cols_to_use)
    fy2023_all_contracts = pd.concat([fy2023_all_contracts, temp_df], ignore_index=True)

# %% [markdown]
# Inspect the fy2023_all_contracts DataFrame structure and content.

# %%
fy2023_all_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6669114 entries, 0 to 6669113
# Data columns (total 27 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   federal_action_obligation                  float64
#  1   total_dollars_obligated                    float64
#  2   current_total_value_of_award               float64
#  3   potential_total_value_of_award             float64
#  4   period_of_performance_start_date           object
#  5   period_of_performance_current_end_date     object
#  6   period_of_performance_potential_end_date   object
#  7   awarding_agency_name                       object
#  8   funding_agency_name                        object
#  9   recipient_uei                              object
#  10  recipient_name                             object
#  11  recipient_country_name                     object
#  12  recipient_state_code                       object
#  13  recipient_state_name                       object
#  14  primary_place_of_performance_country_code  object
#  15  primary_place_of_performance_country_name  object
#  16  primary_place_of_performance_state_code    object
#  17  primary_place_of_performance_state_name    object
#  18  award_or_idv_flag                          object
#  19  award_type                                 object
#  20  type_of_contract_pricing                   object
#  21  product_or_service_code                    object
#  22  product_or_service_code_description        object
#  23  naics_code                                 float64
#  24  naics_description                          object
#  25  extent_competed                            object
#  26  c8a_program_participant                    object
# dtypes: float64(5), object(22)
# memory usage: 1.3+ GB

# %% [markdown]
# ## 3. Creation of csv file

# %% [markdown]
# Export the aggregated DataFrame fy2023_all_contracts, which contains all relevant data from the fiscal year 2023 contract files, to a csv file for future use.

# %%
fy2023_all_contracts.to_csv("..\\Data\\fy2023_all_contracts.csv", index=False)

# %% [markdown]
# This csv file will be use in the following notebook.
